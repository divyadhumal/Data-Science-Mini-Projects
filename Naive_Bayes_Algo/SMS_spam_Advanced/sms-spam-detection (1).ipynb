# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Spam.csv', encoding = 'latin-1')

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 1607   ham  Jus telling u dat i'll b leaving 4 shanghai on...        NaN
# 1620   ham  Fuck babe, I miss you sooooo much !! I wish yo...        NaN
# 3800   ham            It's ok, at least armand's still around        NaN
# 4401   ham  Good FRIENDS CaRE for each Other.. CLoSE Frien...        NaN
# 4014  spam  You will be receiving this week's Triple Echo ...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 1607        NaN        NaN
# 1620        NaN        NaN
# 3800        NaN        NaN
# 4401        NaN        NaN
# 4014        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# 1. Data cleaning
# 2. EDA
# 3. Text Preprocessing
# 4. Model building
# 5. Evaluation
# 6. Improvement
# 7. Website
# 8. Deploy

# %% [markdown]
# ## 1. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   str
#  1   v2          5572 non-null   str
#  2   Unnamed: 2  50 non-null     str
#  3   Unnamed: 3  12 non-null     str
#  4   Unnamed: 4  6 non-null      str
# dtypes: str(5)
# memory usage: 217.8 KB

# %%
# drop last 3 cols
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 3586  ham  Our ride equally uneventful - not too many of ...
# 4711  ham  Thats cool princess! I will cover your face in...
# 2051  ham  Hey darlin.. i can pick u up at college if u t...
# 1494  ham  It has everything to do with the weather. Keep...
# 660   ham  Under the sea, there lays a rock. In the rock,...

# %%
# renaming the cols
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 4826    ham  Yup but it's not giving me problems now so may...
# 5291    ham    Xy trying smth now. U eat already? We havent...
# 5027    ham  Go chase after her and run her over while she'...
# 838    spam  We tried to contact you re our offer of New Vi...
# 3350    ham                       At what time are you coming.

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
# remove duplicates
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ## 2.EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
# Data is imbalanced

# %%
import nltk

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DIVYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\DIVYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DIVYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['num_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(str(x))))
df['num_sentences'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(str(x))))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df['num_sentences'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# ham
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
#spam
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Data Preprocessing
# - Lower case
# - Tokenization
# - Removing special characters
# - Removing stop words and punctuation
# - Stemming

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import string

ps = PorterStemmer()
stop_words = set(stopwords.words('english'))

def transform_text(text):
    text = text.lower()
    words = nltk.word_tokenize(text)
    
    # remove special characters
    words = [word for word in words if word.isalnum()]
    
    # remove stopwords
    words = [word for word in words if word not in stop_words]
    
    # stemming
    words = [ps.stem(word) for word in words]
    
    return " ".join(words)

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
df['text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (2.3.4)
# Requirement already satisfied: pillow in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# get top 30 words
top_words = pd.DataFrame(Counter(spam_corpus).most_common(30))

# plot
sns.barplot(x=top_words[0], y=top_words[1])

plt.xticks(rotation='vertical')
plt.show()

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
# top 30 ham words
top_words = pd.DataFrame(Counter(ham_corpus).most_common(30), columns=['word', 'count'])

# plot
plt.figure(figsize=(12,6))
sns.barplot(x='word', y='count', data=top_words)

plt.title("Top 30 Most Frequent Words in Ham Messages")
plt.xticks(rotation=45)
plt.show()

# %%
# Text Vectorization
# using Bag of Words
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %% [markdown]
# ## 4. Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#X = scaler.fit_transform(X)

# %%
# appending the num_character col to X
#X = np.hstack((X,df['num_characters'].values.reshape(-1,1)))

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.874274661508704
# [[790 106]
#  [ 24 114]]
# 0.5181818181818182

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
# tfidf --> MNB

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from xgboost) (2.3.4)
# Requirement already satisfied: scipy in c:\users\divya\appdata\local\programs\python\python313\lib\site-packages (from xgboost) (1.16.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()

acc, prec = train_classifier(model, X_train, y_train, X_test, y_test)

print(acc, prec)
# Out:
# 0.9709864603481625 1.0

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9758220502901354, 0.9747899159663865)

# %%
import pickle

pickle.dump(model, open('model.pkl','wb'))
pickle.dump(tfidf, open('vectorizer.pkl','wb'))

print("Saved ✅")
# Out:
# Saved ✅

# %%
import os
print(os.listdir())
# Out:
# [' Customer_Complaints.ipynb', ' E-commerceProject.ipynb', ' StudentLinearR.ipynb', '.anaconda', '.atom', '.conda', '.condarc', '.continuum', '.git', '.gitconfig', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.matplotlib', '.packettracer', '.spyder-py3', '.streamlit', '.vscode', 'Airbnb data.csv', 'airbnb project.ipynb', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'archive (5).zip', 'c++ program', 'Churn Analysis.ipynb', 'Cisco Packet Tracer 9.0.0', 'complaints.csv', 'Contacts', 'Cookies', 'Customer Churn.csv', 'data-export (1).csv', 'data.csv', 'DivyaD.ipynb', 'Documents', 'Downloads', 'edb_psqlodbc.exe', 'edb_psqlodbc.exe-20250501212855', 'edb_psqlodbc.exe-20250501212858', 'edb_psqlodbc.exe-20250501212900', 'Favorites', 'helloworld.c', 'Links', 'Local Settings', 'Microsoft', 'model.joblib', 'model.pkl', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{c51e6c88-cf47-11f0-ab73-9a175a915a1f}.TM.blf', 'NTUSER.DAT{c51e6c88-cf47-11f0-ab73-9a175a915a1f}.TM.blf.cnpf', 'NTUSER.DAT{c51e6c88-cf47-11f0-ab73-9a175a915a1f}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{c51e6c88-cf47-11f0-ab73-9a175a915a1f}.TMContainer00000000000000000001.regtrans-ms.cnpf', 'NTUSER.DAT{c51e6c88-cf47-11f0-ab73-9a175a915a1f}.TMContainer00000000000000000002.regtrans-ms', 'NTUSER.DAT{c51e6c88-cf47-11f0-ab73-9a175a915a1f}.TMContainer00000000000000000002.regtrans-ms.cnpf', 'ntuser.ini', 'OneDrive', 'postgresql_13.exe', 'PrintHood', 'PyCharmMiscProject', 'PycharmProjects', 'Recent', 'Sample - Superstore.csv', 'Saved Games', 'scikit_learn_data', 'Searches', 'SendTo', 'sms-spam-detection-fixed.ipynb', 'sms-spam-detection.ipynb', 'Spam.csv', 'Start Menu', 'StudentPerformance.csv', 'Templates', 'Untitled.ipynb', 'untitled.py', 'untitled.txt', 'Untitled1.ipynb', 'untitled1.py', 'untitled1.txt', 'Untitled2.ipynb', 'untitled2.txt', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Untitled8.ipynb', 'Untitled9.ipynb', 'vectorizer.joblib', 'vectorizer.pkl', 'Videos']

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9758220502901354
# Precision -  0.9747899159663865
# For  KN
# Accuracy -  0.9052224371373307
# Precision -  1.0
# For  NB
# Accuracy -  0.9709864603481625
# Precision -  1.0
# For  DT
# Accuracy -  0.9303675048355899
# Precision -  0.83
# For  LR
# Accuracy -  0.9555125725338491
# Precision -  0.96
# c:\Users\DIVYA\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\DIVYA\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# For  RF
# Accuracy -  0.9738878143133463
# Precision -  0.9826086956521739

# %%
import pandas as pd

performance_df = pd.DataFrame({
    'Model': list(clfs.keys()),
    'Accuracy': accuracy_scores,
    'Precision': precision_scores
})

# %%
performance_df.reset_index(drop=True, inplace=True)

# %%
performance_df
# Out:
#        Model  Accuracy  Precision
# 0        SVC  0.975822   0.974790
# 1         KN  0.905222   1.000000
# 2         NB  0.970986   1.000000
# 3         DT  0.927466   0.811881
# 4         LR  0.958414   0.970297
# 5         RF  0.975822   0.982906
# 6   AdaBoost  0.960348   0.929204
# 7        BgC  0.958414   0.868217
# 8        ETC  0.974855   0.974576
# 9       GBDT  0.946809   0.919192
# 10       xgb  0.967118   0.948276

# %%
performance_df1 = pd.melt(performance_df, id_vars="Model")

# %%
performance_df1
# Out:
#        Model   variable     value
# 0        SVC   Accuracy  0.975822
# 1         KN   Accuracy  0.905222
# 2         NB   Accuracy  0.970986
# 3         DT   Accuracy  0.927466
# 4         LR   Accuracy  0.958414
# 5         RF   Accuracy  0.975822
# 6   AdaBoost   Accuracy  0.960348
# 7        BgC   Accuracy  0.958414
# 8        ETC   Accuracy  0.974855
# 9       GBDT   Accuracy  0.946809
# 10       xgb   Accuracy  0.967118
# 11       SVC  Precision  0.974790
# 12        KN  Precision  1.000000
# 13        NB  Precision  1.000000
# 14        DT  Precision  0.811881
# 15        LR  Precision  0.970297
# 16        RF  Precision  0.982906
# 17  AdaBoost  Precision  0.929204
# 18       BgC  Precision  0.868217
# 19       ETC  Precision  0.974576
# 20      GBDT  Precision  0.919192
# 21       xgb  Precision  0.948276

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(
    x='Model', 
    y='value',
    hue='variable',
    data=performance_df1,
    kind='bar',
    height=5
)

plt.ylim(0.5, 1.0)
plt.xticks(rotation=90)
plt.show()

# %%
# model improve
# 1. Change the max_features parameter of TfIdf

# %%
temp_df = pd.DataFrame({
    'Algorithm': list(clfs.keys()),
    'Accuracy_max_ft_3000': accuracy_scores,
    'Precision_max_ft_3000': precision_scores
}).sort_values('Precision_max_ft_3000', ascending=False)

# %%
temp_df = pd.DataFrame({
    'Algorithm': list(clfs.keys()),
    'Accuracy_max_ft_3000': accuracy_scores,
    'Precision_max_ft_3000': precision_scores
})

temp_df = temp_df.sort_values(by='Precision_max_ft_3000', ascending=False).reset_index(drop=True)
print(temp_df)
# Out:
#    Algorithm  Accuracy_max_ft_3000  Precision_max_ft_3000
# 0         KN              0.905222               1.000000
# 1         NB              0.970986               1.000000
# 2         RF              0.975822               0.982906
# 3        SVC              0.975822               0.974790
# 4        ETC              0.974855               0.974576
# 5         LR              0.958414               0.970297
# 6        xgb              0.967118               0.948276
# 7   AdaBoost              0.960348               0.929204
# 8       GBDT              0.946809               0.919192
# 9        BgC              0.958414               0.868217
# 10        DT              0.927466               0.811881

# %%
temp_df.rename(columns={'Algorithm': 'Model'}, inplace=True)

new_df = performance_df.merge(temp_df, on='Model')

# %%
new_df_scaled = new_df.merge(temp_df,on='Model')
print(new_df_scaled)
# Out:
#        Model  Accuracy  Precision  Accuracy_max_ft_3000_x  \
# 0        SVC  0.975822   0.974790                0.975822
# 1         KN  0.905222   1.000000                0.905222
# 2         NB  0.970986   1.000000                0.970986
# 3         DT  0.927466   0.811881                0.927466
# 4         LR  0.958414   0.970297                0.958414
# 5         RF  0.975822   0.982906                0.975822
# 6   AdaBoost  0.960348   0.929204                0.960348
# 7        BgC  0.958414   0.868217                0.958414
# 8        ETC  0.974855   0.974576                0.974855
# 9       GBDT  0.946809   0.919192                0.946809
# 10       xgb  0.967118   0.948276                0.967118
#
#     Precision_max_ft_3000_x  Accuracy_max_ft_3000_y  Precision_max_ft_3000_y
# 0                  0.974790                0.975822                 0.974790
# 1                  1.000000                0.905222                 1.000000
# 2                  1.000000                0.970986                 1.000000
# 3                  0.811881                0.927466                 0.811881
# 4                  0.970297                0.958414                 0.970297
# 5                  0.982906                0.975822                 0.982906
# 6                  0.929204                0.960348                 0.929204
# 7                  0.868217                0.958414                 0.868217
# 8                  0.974576                0.974855                 0.974576
# 9                  0.919192                0.946809                 0.919192
# 10                 0.948276                0.967118                 0.948276

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_num_chars':accuracy_scores,'Precision_num_chars':precision_scores}).sort_values('Precision_num_chars',ascending=False)

# %%
new_df = new_df_scaled.merge(
    temp_df,
    left_on='Model',
    right_on='Algorithm'
)

# %%
print("new_df_scaled columns:", new_df_scaled.columns)
print("temp_df columns:", temp_df.columns)
# Out:
# new_df_scaled columns: Index(['Model', 'Accuracy', 'Precision', 'Accuracy_max_ft_3000_x',
#        'Precision_max_ft_3000_x', 'Accuracy_max_ft_3000_y',
#        'Precision_max_ft_3000_y'],
#       dtype='object')
# temp_df columns: Index(['Algorithm', 'Accuracy_num_chars', 'Precision_num_chars'], dtype='object')

# %%
# Voting Classifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier

# models
svc = SVC(kernel='sigmoid', gamma=1.0, probability=True)
mnb = MultinomialNB()
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)

# voting classifier
voting = VotingClassifier(
    estimators=[
        ('svc', svc),
        ('mnb', mnb),
        ('etc', etc)
    ],
    voting='soft'   # important!
)

# %%
voting = VotingClassifier(estimators=[('svm', svc), ('nb', mnb), ('et', etc)],voting='soft')

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9816247582205029
# Precision 0.9917355371900827

# %%
# Applying stacking
estimators=[('svm', svc), ('nb', mnb), ('et', etc)]
final_estimator=RandomForestClassifier()

# %%
from sklearn.ensemble import StackingClassifier

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)

# %%
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 clf.fit(X_train,y_train)
#       2 y_pred = clf.predict(X_test)
#       3 print("Accuracy",accuracy_score(y_test,y_pred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_stacking.py:672, in StackingClassifier.fit(self, X, y, sample_weight)
#     670     self.classes_ = self._label_encoder.classes_
#     671     y_encoded = self._label_encoder.transform(y)
# --> 672 return super().fit(X, y_encoded, sample_weight)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_stacking.py:224, in _BaseStacking.fit(self, X, y, sample_weight)
#     219             self.estimators_.append(estimator)
#     220 else:
#     221     # Fit the base estimators on the whole training data. Those
#     222     # base estimators will be used in transform, predict, and
#     223     # predict_proba. They are exposed publicly.
# --> 224     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     225         delayed(_fit_single_estimator)(clone(est), X, y, fit_params)
#     226         for est in all_estimators
#     227         if est != "drop"
#     228     )
#     230 self.named_estimators_ = Bunch()
#     231 est_fitted_idx = 0
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:40, in _fit_single_estimator(estimator, X, y, fit_params, message_clsname, message)
#      38 else:
#      39     with _print_elapsed_time(message_clsname, message):
# ---> 40         estimator.fit(X, y, **fit_params)
#      41 return estimator
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:328, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     314 libsvm.set_verbosity_wrap(self.verbose)
#     316 # we don't pass **self.get_params() to allow subclasses to
#     317 # add other parameters to __init__
#     318 (
#     319     self.support_,
#     320     self.support_vectors_,
#     321     self._n_support,
#     322     self.dual_coef_,
#     323     self.intercept_,
#     324     self._probA,
#     325     self._probB,
#     326     self.fit_status_,
#     327     self._num_iter,
# --> 328 ) = libsvm.fit(
#     329     X,
#     330     y,
#     331     svm_type=solver_type,
#     332     sample_weight=sample_weight,
#     333     class_weight=getattr(self, "class_weight_", np.empty(0)),
#     334     kernel=kernel,
#     335     C=self.C,
#     336     nu=self.nu,
#     337     probability=self.probability,
#     338     degree=self.degree,
#     339     shrinking=self.shrinking,
#     340     tol=self.tol,
#     341     cache_size=self.cache_size,
#     342     coef0=self.coef0,
#     343     gamma=self._gamma,
#     344     epsilon=self.epsilon,
#     345     max_iter=self.max_iter,
#     346     random_seed=random_seed,
#     347 )
#     349 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
import pickle

model = pickle.load(open('model.pkl','rb'))
vectorizer = pickle.load(open('vectorizer.pkl','rb'))

# %%
import pickle

# load files
model = pickle.load(open('model.pkl','rb'))
vectorizer = pickle.load(open('vectorizer.pkl','rb'))

# sample input
sample = ["Congratulations! You won a free lottery"]

# transform text
transformed = vectorizer.transform(sample)

# predict
prediction = model.predict(transformed)

print(prediction)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[130], line 14
#      11 transformed = vectorizer.transform(sample)
#      13 # predict
# ---> 14 prediction = model.predict(transformed)
#      16 print(prediction)
#
# File ~\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:100, in _BaseNB.predict(self, X)
#      86 def predict(self, X):
#      87     """
#      88     Perform classification on an array of test vectors X.
#      89
#    (...)
#      98         Predicted target values for X.
#      99     """
# --> 100     check_is_fitted(self)
#     101     X = self._check_X(X)
#     102     jll = self._joint_log_likelihood(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This MultinomialNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\DIVYA

# %%
pickle.dump(tfidf, open(r'C:\Users\DIVYA\OneDrive\Desktop\SMS Classifier\vectorizer.pkl','wb'))
pickle.dump(model, open(r'C:\Users\DIVYA\OneDrive\Desktop\SMS Classifier\model.pkl','wb'))

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\DIVYA

# %%
import pickle

# save files
with open('vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)

with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

print("Files saved successfully ✅")
# Out:
# Files saved successfully ✅

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\DIVYA

# %%
import pickle

model = pickle.load(open('model.pkl','rb'))
vectorizer = pickle.load(open('vectorizer.pkl','rb'))

sample = ["Congratulations! You won a free lottery"]

transformed = vectorizer.transform(sample)
prediction = model.predict(transformed)

print(prediction)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[127], line 9
#       6 sample = ["Congratulations! You won a free lottery"]
#       8 transformed = vectorizer.transform(sample)
# ----> 9 prediction = model.predict(transformed)
#      11 print(prediction)
#
# File ~\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:100, in _BaseNB.predict(self, X)
#      86 def predict(self, X):
#      87     """
#      88     Perform classification on an array of test vectors X.
#      89
#    (...)
#      98         Predicted target values for X.
#      99     """
# --> 100     check_is_fitted(self)
#     101     X = self._check_X(X)
#     102     jll = self._joint_log_likelihood(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This MultinomialNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
